# %%
import urllib3
import json
import pandas as pd
from pandas import json_normalize
from sqlalchemy import create_engine

# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_countries&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_countries = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# [{'country_id': '10', 'country_name': 'Albania', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/10_albania.png'}, {'country_id': '11', 'country_name': 'Algeria', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/11_algeria.png'}, {'country_id': '12', 'country_name': 'Andorra', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/12_andorra.png'}, {'country_id': '13', 'country_name': 'Angola', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/13_angola.png'}, {'country_id': '14', 'country_name': 'Argentina', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/14_argentina.png'}, {'country_id': '15', 'country_name': 'Armenia', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/15_armenia.png'}, {'country_id': '16', 'country_name': 'Aruba', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/16_aruba.png'}, {'country_id': '17', 'country_name': 'Australia', 'country_logo': 'h
# ...

# %%
df_countries.loc[df_countries['country_name'] == 'Brazil']
# Out:
#    country_id country_name                                       country_logo
# 22         27       Brazil  https://apiv3.apifootball.com/badges/logo_coun...

# %%
# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_leagues&country_id=27&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_ligas = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# [{'country_id': '27', 'country_name': 'Brazil', 'league_id': '99', 'league_name': 'Serie A', 'league_season': '2023', 'league_logo': 'https://apiv3.apifootball.com/badges/logo_leagues/99_serie-a.png', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/27_brazil.png'}, {'country_id': '27', 'country_name': 'Brazil', 'league_id': '75', 'league_name': 'Serie B', 'league_season': '2023', 'league_logo': 'https://apiv3.apifootball.com/badges/logo_leagues/75_serie-b.png', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/27_brazil.png'}, {'country_id': '27', 'country_name': 'Brazil', 'league_id': '349', 'league_name': 'Copa do Brasil', 'league_season': '2024', 'league_logo': 'https://apiv3.apifootball.com/badges/logo_leagues/349_copa-do-brasil.png', 'country_logo': 'https://apiv3.apifootball.com/badges/logo_country/27_brazil.png'}, {'country_id': '27', 'country_name': 'Brazil', 'league_id': '77', 'league_name': 'Acreano', 'league_season': '2024', 'league_logo
# ...

# %%
df_ligas.loc[df_ligas['league_name'] == 'Copa do Brasil']
# Out:
#   country_id country_name league_id     league_name league_season
# 2         27       Brazil       349  Copa do Brasil          2024  \
#
#                                          league_logo
# 2  https://apiv3.apifootball.com/badges/logo_leag...  \
#
#                                         country_logo
# 2  https://apiv3.apifootball.com/badges/logo_coun...

# %%
# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_teams&league_id=349&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_teams = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# [{'team_key': '559', 'team_name': 'Internacional', 'team_country': 'Brazil', 'team_founded': '1909', 'team_badge': 'https://apiv3.apifootball.com/badges/559_internacional.jpg', 'venue': {'venue_name': 'Estádio José Pinheiro Borda', 'venue_address': 'Avenida Padre Cacique 891, Bairro Menino Deus', 'venue_city': 'Porto Alegre, Rio Grande do Sul', 'venue_capacity': '50128', 'venue_surface': 'grass'}, 'players': [{'player_key': 2547971844, 'player_id': '2547971844', 'player_image': 'https://apiv3.apifootball.com/badges/players/126691_anthoni.jpg', 'player_name': 'Anthoni', 'player_number': '24', 'player_country': '', 'player_type': 'Goalkeepers', 'player_age': '22', 'player_match_played': '9', 'player_goals': '0', 'player_yellow_cards': '0', 'player_red_cards': '0', 'player_injured': 'No', 'player_substitute_out': '0', 'player_substitutes_on_bench': '1', 'player_assists': '0', 'player_birthdate': '2002-01-23', 'player_is_captain': '', 'player_shots_total': '', 'player_goals_conceded': ''
# ...

# %%
df_teams.loc[df_teams['team_name'] == 'Olaria']
# Out:
#    team_key team_name team_country team_founded
# 50     1887    Olaria       Brazil         1915  \
#
#                                            team_badge
# 50  https://apiv3.apifootball.com/badges/1887_olar...  \
#
#                                                 venue
# 50  {'venue_name': 'Estádio Mourão Filho', 'venue_...  \
#
#                                               players
# 50  [{'player_key': 1274864827, 'player_id': '1274...  \
#
#                                               coaches
# 50  [{'coach_name': '', 'coach_country': '', 'coac...

# %%
# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_standings&league_id=349&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_standings = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# {'error': 404, 'message': 'Standing not found!'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 21
#      19     # Faça algo com os dados
#      20     print(data)
# ---> 21     df_standings = pd.DataFrame(data)
#      22 else:
#      23     print('Falha na solicitação:', response.status)
#
# File c:\Users\B042304\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
# ...

# %%
df_standings
# Out:
#    country_name league_id     league_name team_id        team_name
# 0       England       152  Premier League      84        Liverpool  \
# 1       England       152  Premier League      80  Manchester City
# 2       England       152  Premier League     141          Arsenal
# 3       England       152  Premier League    3088      Aston Villa
# 4       England       152  Premier League     164        Tottenham
# 5       England       152  Premier League     102   Manchester Utd
# 6       England       152  Premier League    3079         Brighton
# 7       England       152  Premier League    3081         West Ham
# 8       England       152  Premier League    3077           Wolves
# 9       England       152  Premier League    3100        Newcastle
# 10      England       152  Premier League      88          Chelsea
# 11      England       152  Premier League    3085           Fulham
# 12      England       152  Premier League    3429   Crystal Palace
# ...

# %%
# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_events&from=2024-02-28&to=2024-02-28&league_id=349&timezone=America/Sao_Paulo&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_events = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# [{'match_id': '343354', 'country_id': '27', 'country_name': 'Brazil', 'league_id': '349', 'league_name': 'Copa do Brasil - 1st Round', 'match_date': '2024-02-28', 'match_status': '', 'match_time': '19:30', 'match_hometeam_id': '1957', 'match_hometeam_name': 'Petrolina', 'match_hometeam_score': '', 'match_awayteam_name': 'Cascavel', 'match_awayteam_id': '1818', 'match_awayteam_score': '', 'match_hometeam_halftime_score': '', 'match_awayteam_halftime_score': '', 'match_hometeam_extra_score': '', 'match_awayteam_extra_score': '', 'match_hometeam_penalty_score': '', 'match_awayteam_penalty_score': '', 'match_hometeam_ft_score': '', 'match_awayteam_ft_score': '', 'match_hometeam_system': '', 'match_awayteam_system': '', 'match_live': '0', 'match_round': '', 'match_stadium': 'Estádio Paulo de Souza Coelho (Petrolina, Pernambuco)', 'match_referee': '', 'team_home_badge': 'https://apiv3.apifootball.com/badges/1957_petrolina.jpg', 'team_away_badge': 'https://apiv3.apifootball.com/badges/1818_
# ...

# %%
df = df_events.loc[df_events['match_hometeam_name'] == 'Olaria']

# Configurar a conexão com o banco de dados SQL Server
engine = create_engine('mssql+pyodbc:///?odbc_connect=' +
                       'DRIVER={ODBC Driver 17 for SQL Server};' +
                       'SERVER=SQLGDNCLI;' +
                       'DATABASE=WORKSPACE;' +
                       'Trusted_Connection=yes;')

# Inserir o DataFrame na tabela do SQL Server
df.to_csv('C:\\Users\\B042304\Downloads\\teste2.csv', index=False)

# %%
# Expandir os dicionários em um novo DataFrame
df_new = pd.json_normalize(df['statistics'])

df_new0 = pd.json_normalize(df_new[0])
df_new1 = pd.json_normalize(df_new[1])
df_new2 = pd.json_normalize(df_new[2])
df_new3 = pd.json_normalize(df_new[3])
df_new4 = pd.json_normalize(df_new[4])
df_new5 = pd.json_normalize(df_new[5])
df_new6 = pd.json_normalize(df_new[6])
df_new7 = pd.json_normalize(df_new[7])
df_new8 = pd.json_normalize(df_new[8])



df_concatenated = pd.concat([df_new0,df_new1,df_new2,df_new3,df_new4,df_new5,df_new6,df_new7,df_new8])

df_concatenated
# Out:
#                 type home away
# 0           Throw In    0    0
# 0          Free Kick    0    0
# 0          Goal Kick    0    0
# 0            Penalty    0    0
# 0       Substitution    0    0
# 0            Attacks   91  100
# 0  Dangerous Attacks   27   47
# 0          On Target    5    1
# 0         Off Target    1    1

# %%
# URL da API de futebol
url = 'https://apiv3.apifootball.com/?action=get_statistics&match_id=343358&APIkey=462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'

# Adicione seu token de acesso da API de futebol
headers = {
    'Authorization': '462a46752da5960eab532285831f49114d0feaa9dbe68721ddd9de2ebc976399'
}

# Crie um PoolManager
http = urllib3.PoolManager()

# Faça uma solicitação GET
response = http.request('GET', url, headers=headers)

# Verifique se a resposta foi bem-sucedida (código de status 200)
if response.status == 200:
    # Decodifique a resposta JSON
    data = json.loads(response.data.decode('utf-8'))
    # Faça algo com os dados
    print(data)
    df_statistcs = pd.DataFrame(data)
else:
    print('Falha na solicitação:', response.status)
# Out:
# {'343358': {'statistics': [{'type': 'Throw In', 'home': '0', 'away': '0'}, {'type': 'Free Kick', 'home': '0', 'away': '0'}, {'type': 'Goal Kick', 'home': '0', 'away': '0'}, {'type': 'Penalty', 'home': '0', 'away': '0'}, {'type': 'Substitution', 'home': '0', 'away': '0'}, {'type': 'Attacks', 'home': '109', 'away': '123'}, {'type': 'Dangerous Attacks', 'home': '37', 'away': '63'}, {'type': 'On Target', 'home': '5', 'away': '2'}, {'type': 'Off Target', 'home': '2', 'away': '5'}], 'statistics_1half': [{'type': 'Throw In', 'home': '0', 'away': '0'}, {'type': 'Free Kick', 'home': '0', 'away': '0'}, {'type': 'Goal Kick', 'home': '0', 'away': '0'}, {'type': 'Penalty', 'home': '0', 'away': '0'}, {'type': 'Substitution', 'home': '0', 'away': '0'}, {'type': 'Attacks', 'home': '72', 'away': '88'}, {'type': 'Dangerous Attacks', 'home': '22', 'away': '40'}, {'type': 'On Target', 'home': '5', 'away': '1'}, {'type': 'Off Target', 'home': '1', 'away': '1'}], 'player_statistics': []}}

# %%
df_new = pd.json_normalize(df_statistcs['343358'])

# Normalizar colunas que contêm dicionários aninhados
for col in df_new.columns:
    if any(isinstance(val, dict) for val in df[col]):
        df = pd.concat([df.drop(col, axis=1), pd.json_normalize(df[col]).add_prefix(col+'_')], axis=1)

# Imprimir o DataFrame com todas as colunas normalizadas
df
# Out:
#   match_id country_id country_name league_id                 league_name
# 1   343358         27       Brazil       349  Copa do Brasil - 1st Round  \
#
#    match_date match_status match_time match_hometeam_id match_hometeam_name
# 1  2024-02-28           52      15:30              1887              Olaria  \
#
#    ... 343358                                            0
# 1  ...    NaN         type home away
# 0  Throw In    0    0  \
#
#                                                1
# 1          type home away
# 0  Free Kick    0    0  \
#
#                                                2
# 1          type home away
# 0  Goal Kick    0    0  \
#
#                                            3
# 1        type home away
# 0  Penalty    0    0  \
#
#                                                    4
# 1             type home away
# 0  Substitution    0...  \
#
#                                            5
# 1        type home away
# 0  Attacks  109  123  \
#
# ...
